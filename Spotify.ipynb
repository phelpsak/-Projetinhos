# %%
# Análise Exploratória Spotify!

# %%
import pandas as pd
import datetime as dt

# %%
base = pd.read_csv("spotify_top_charts_22.csv")

# %%
base.head()
# Out:
#                                     uri  \
# 0  spotify:track:02MWAaffLxlfxAUY7c5dvx
# 1  spotify:track:5PjdY0CKGZdEuoNab3yDmX
# 2  spotify:track:3IAfUEeaXRX9s9UdKOJrFI
# 3  spotify:track:1HhNoOuqm1a5MXYEgAFl8o
# 4  spotify:track:4fouWK6XVHhzl78KzQ1UjL
#
#                                       artist_names  \
# 0                                    Glass Animals
# 1                     The Kid LAROI, Justin Bieber
# 2                                           Anitta
# 3  Imagine Dragons, JID, Arcane, League of Legends
# 4                                            GAYLE
#
#                                           track_name  peak_rank  \
# 0                                         Heat Waves          1
# 1                          STAY (with Justin Bieber)          1
# 2                                           Envolver          3
# 3  Enemy (with JID) - from the series Arcane Leag...          3
# 4                                            abcdefu          1
#
# ...

# %%
base.tail()
# Out:
#                                       uri  \
# 641  spotify:track:0So2sgVa8aJiARPl2P29u2
# 642  spotify:track:1TUuhV75FeOF6UObRsABo2
# 643  spotify:track:3GbQcjKWT7eVpUfzqwUjxv
# 644  spotify:track:7My9ca9QEIR8MvIOdIrTWA
# 645  spotify:track:4axSuOg3BqsowKjRpj59RU
#
#                               artist_names  \
# 641                                  SALES
# 642                          Morgan Wallen
# 643  Lil Nas X, YoungBoy Never Broke Again
# 644                     Eminem, Snoop Dogg
# 645                           Taylor Swift
#
#                                             track_name  peak_rank  \
# 641                                 Pope Is a Rockstar        108
# 642                                  Don't Think Jesus         96
# 643  Late To Da Party (F*CK BET) (feat. YoungBoy Ne...         86
# 644             From The D 2 The LBC (with Snoop Dogg)        135
# 645  Carolina - From The Motion Picture “Where The ...        152
#
# ...

# %%
base.shape
# Out:
# (646, 17)

# %%
display(base)
# Out:
#                                       uri  \
# 0    spotify:track:02MWAaffLxlfxAUY7c5dvx
# 1    spotify:track:5PjdY0CKGZdEuoNab3yDmX
# 2    spotify:track:3IAfUEeaXRX9s9UdKOJrFI
# 3    spotify:track:1HhNoOuqm1a5MXYEgAFl8o
# 4    spotify:track:4fouWK6XVHhzl78KzQ1UjL
# ..                                    ...
# 641  spotify:track:0So2sgVa8aJiARPl2P29u2
# 642  spotify:track:1TUuhV75FeOF6UObRsABo2
# 643  spotify:track:3GbQcjKWT7eVpUfzqwUjxv
# 644  spotify:track:7My9ca9QEIR8MvIOdIrTWA
# 645  spotify:track:4axSuOg3BqsowKjRpj59RU
#
#                                         artist_names  \
# 0                                      Glass Animals
# 1                       The Kid LAROI, Justin Bieber
# 2                                             Anitta
# 3    Imagine Dragons, JID, Arcane, League of Legends
# 4                                              GAYLE
# ..                                               ...
# 641                                            SALES
# ...

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   uri               646 non-null    object
#  1   artist_names      646 non-null    object
#  2   track_name        646 non-null    object
#  3   peak_rank         646 non-null    int64
#  4   weeks_on_chart    646 non-null    int64
#  5   danceability      646 non-null    float64
#  6   energy            646 non-null    float64
#  7   key               646 non-null    int64
#  8   loudness          646 non-null    float64
#  9   mode              646 non-null    int64
#  10  speechiness       646 non-null    float64
#  11  acousticness      646 non-null    float64
#  12  instrumentalness  646 non-null    float64
#  13  liveness          646 non-null    float64
#  14  tempo             646 non-null    float64
#  15  time_signature    646 non-null    int64
# ...

# %%
base.dtypes
# Out:
# uri                  object
# artist_names         object
# track_name           object
# peak_rank             int64
# weeks_on_chart        int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# tempo               float64
# time_signature        int64
# duration_ms           int64
# dtype: object

# %%
base.isnull().sum()
# Out:
# uri                 0
# artist_names        0
# track_name          0
# peak_rank           0
# weeks_on_chart      0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# tempo               0
# time_signature      0
# duration_ms         0
# dtype: int64

# %%
base['track_name'].value_counts()
# Out:
# Heat Waves                                                      1
# Just A Cloud Away                                               1
# Enséñame a Bailar                                               1
# Die Young (feat. 347aidan)                                      1
# Thousand Miles                                                  1
#                                                                ..
# Doja                                                            1
# BREAK MY SOUL                                                   1
# About Damn Time                                                 1
# STAYING ALIVE (feat. Drake & Lil Baby)                          1
# Carolina - From The Motion Picture “Where The Crawdads Sing”    1
# Name: track_name, Length: 646, dtype: int64

# %%
base.describe()
# Out:
#         peak_rank  weeks_on_chart  danceability      energy         key  \
# count  646.000000      646.000000    646.000000  646.000000  646.000000
# mean    65.922601       19.498452      0.674426    0.640836    5.086687
# std     57.004503       37.813937      0.151527    0.165478    3.622314
# min      1.000000        1.000000      0.193000    0.021800    0.000000
# 25%     15.000000        1.000000      0.569000    0.532500    1.000000
# 50%     51.500000        5.000000      0.700000    0.652000    5.000000
# 75%    108.750000       19.750000      0.790750    0.769000    8.000000
# max    200.000000      269.000000      0.985000    0.972000   11.000000
#
#          loudness        mode  speechiness  acousticness  instrumentalness  \
# count  646.000000  646.000000   646.000000    646.000000        646.000000
# mean    -6.356034    0.577399     0.109797      0.255699          0.013686
# std      2.627462    0.494356     0.102167      0.262595          0.077836
# ...

# %%
base.plot(kind='line',figsize=(5,30),subplots=True);

# %%
base_excel = base[base['duration_ms'] >= 100]
base_excel.to_excel('Verificar.xlsx')

# %%
base.duration_ms.value_counts()
# Out:
# 229283    2
# 188369    2
# 160000    2
# 164000    2
# 177000    2
#          ..
# 178176    1
# 237895    1
# 172235    1
# 179551    1
# 264439    1
# Name: duration_ms, Length: 634, dtype: int64

# %%
base.duration_ms.value_counts().plot(kind='bar');

# %%
base['duration_ms'].hist();

# %%
base[base['duration_ms'] == base['duration_ms'].min()]
# Out:
#                                       uri artist_names track_name  peak_rank  \
# 616  spotify:track:5lVmzrKaqPpPYtF7udoiNq        Drake      Intro         61
#
#      weeks_on_chart  danceability  energy  key  loudness  mode  speechiness  \
# 616               1         0.193  0.0218    0    -31.16     0       0.0389
#
#      acousticness  instrumentalness  liveness    tempo  time_signature  \
# 616         0.955              0.88     0.117  125.501               3
#
#      duration_ms
# 616        36935
